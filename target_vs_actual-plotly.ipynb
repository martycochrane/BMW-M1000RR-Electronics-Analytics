# %%
import matplotlib.pylab as plt
import numpy as np
from mpl_toolkits import mplot3d

#fig = plt.figure()

x = [15,20,25,30,35,40,45,50,55,60]
y = [50,65,85,105,125,145,165,185,205,225]
#y = [60,55,50,45,40,35,30,25,20,15]
x, y = np.meshgrid(x, y)
z = np.array([
    [24,21.6,20.9,19.7,18.1,16.2,13.4,9.2,5.7,1.6],
    [22.3,21.7,21,19.8,18.2,16.4,13.8,9.4,5.7,1.8],
    [22.4,21.8,21.1,19.9,18.3,16.5,14.1,9.5,5.6,1.9],
    [22.6,22,21.2,20.1,18.4,16.6,14.2,9.6,5.7,2.1],
    [22.7,22.1,21.4,20.2,18.6,16.8,14.3,9.6,5.2,2],
    [22.8,22.2,21.5,20.3,18.7,16.8,14.3,9.6,5.1,1.8],
    [22.9,22.4,21.6,20.4,18.8,16.8,14.3,9.7,5.2,1.4],
    [23,22.5,21.8,20.6,18.9,16.9,14.2,9.9,5.9,2.2],
    [23.1,22.6,21.9,20.7,19,17,14.2,10.2,6.6,3.3],
    [23.2,22.7,22.1,20.8,19.1,17.1,14.3,10.4,7.1,4]
])

ax = plt.axes(projection="3d")
#ax.plot_surface(x, y, z, cmap='RdBu', zorder=1)
ax.set_ylabel("Speed (km/h)")
ax.set_xlabel("Lean Angle (degrees)")
ax.set_zlabel("Slip (%)")
#ax.set_ylim(60, 20)

#plt.gca().invert_xaxis()
#plt.gca().invert_yaxis()

x1=[52.8
,52.5
,51.8
,51.1
,49.6
,47.6
,45.9
,44.8
,44.8
,44.6
,43.7
,43
,43.2
,43.9
,44.3
,44.5
,44.6
,44.3
,43.6
,43.2
,43.6
,44
,44.2
,44.7
,45.3
,45.1
,46.4
,47.8
,48.3
,48.2
,49.5
,51.4
,52.5
,52.7
,52.8
,53
,53.3
,52.9
,52.7
,52.8
,52.7
,52.6
,52.5
,52.1
,50.7
,48.5
,46.7
,45.7
,45
,44.5
,44.6
,45.3
,46.2
,46.4
,46.1
,46.2
,46.4
,46.2
,45.7
,44.9
,44.5
,44.5
,44.1
,43.6
,43.2
,42.2
,40
,37.7
,37.1
,37.1
]
y1=[75.1
,76.6
,78.3
,80.4
,82
,84.2
,87.2
,90.5
,94.4
,96.8
,99.5
,103.5
,106.5
,111.1
,113.1
,118.1
,120.1
,124.4
,127.2
,131.6
,135.7
,138.6
,141.9
,143.9
,145.8
,147.8
,151.5
,152.3
,154
,156.6
,158.5
,160.5
,162.5
,163.5
,165.6
,165.7
,166.9
,167.8
,168.5
,169.8
,169.8
,170.3
,171.6
,172.1
,171.8
,173
,174.4
,175.8
,177.7
,179.5
,181.1
,183.2
,184.8
,185.7
,188
,189.9
,190.8
,191.8
,193.4
,194.8
,197.5
,198.3
,199.2
,200.7
,201.6
,201.8
,203.5
,205.8
,208.2
,202.8
]
z1=[2.26
,2.88
,4.09
,4.7
,5.73
,8.12
,9
,10.15
,10.07
,8.84
,10.96
,11.6
,12.34
,10.67
,12.23
,13.48
,12.37
,11.55
,10.99
,11.93
,10.07
,9.86
,10.2
,5.04
,6.36
,9.65
,10.47
,4.64
,6.03
,7.78
,7.49
,5.37
,4.01
,3.99
,4.14
,3.62
,3.4
,3.46
,3.84
,3.26
,3.67
,3.99
,4.23
,4.1
,4.84
,5.68
,6.11
,6.77
,7
,7.64
,8.18
,9.09
,7.99
,7.38
,8.54
,8.14
,7.9
,8.22
,8.21
,8.87
,9.34
,8.58
,8.67
,8.74
,8.36
,7.63
,7.51
,8.03
,4.45
,-0.4
]

#ax.plot_surface(x, y, z, cmap='RdBu', zorder=0)
ax.plot_wireframe(x, y, z,cmap='RdBu', zorder=0)

ax.plot3D(x1, y1, z1, 'red', zorder=2)

# c is just the colour scale to use. I thought at first it was the plot points but when
# i created my own C array then I saw all it did was change the colour range 
#ax.scatter3D(x1, y1, z1, c=z1, cmap='cividis', zorder=3);

plt.show()

# %%
from turtle import width
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv


x = [15,20,25,30,35,40,45,50,55,60]
y = [50,65,85,105,125,145,165,185,205,225]
#y = [60,55,50,45,40,35,30,25,20,15]
x, y = np.meshgrid(x, y)
z = np.array([
    [24,21.6,20.9,19.7,18.1,16.2,13.4,9.2,5.7,1.6],
    [22.3,21.7,21,19.8,18.2,16.4,13.8,9.4,5.7,1.8],
    [22.4,21.8,21.1,19.9,18.3,16.5,14.1,9.5,5.6,1.9],
    [22.6,22,21.2,20.1,18.4,16.6,14.2,9.6,5.7,2.1],
    [22.7,22.1,21.4,20.2,18.6,16.8,14.3,9.6,5.2,2],
    [22.8,22.2,21.5,20.3,18.7,16.8,14.3,9.6,5.1,1.8],
    [22.9,22.4,21.6,20.4,18.8,16.8,14.3,9.7,5.2,1.4],
    [23,22.5,21.8,20.6,18.9,16.9,14.2,9.9,5.9,2.2],
    [23.1,22.6,21.9,20.7,19,17,14.2,10.2,6.6,3.3],
    [23.2,22.7,22.1,20.8,19.1,17.1,14.3,10.4,7.1,4]
])

#z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
#z = z_data.values
#sh_0, sh_1 = z.shape
#x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)

x1=[52.8,52.5,51.8,51.1,49.6,47.6,45.9,44.8,44.8,44.6,43.7,43,43.2,43.9,44.3,44.5,44.6,44.3,43.6,43.2,43.6,44,44.2,44.7,45.3,45.1,46.4,47.8,48.3,48.2,49.5,51.4,52.5,52.7,52.8,53,53.3,52.9,52.7,52.8,52.7,52.6,52.5,52.1,50.7,48.5,46.7,45.7,45,44.5,44.6,45.3,46.2,46.4,46.1,46.2,46.4,46.2,45.7,44.9,44.5,44.5,44.1,43.6,43.2,42.2,40,37.7,37.1,37.1]
y1=[75.1,76.6,78.3,80.4,82,84.2,87.2,90.5,94.4,96.8,99.5,103.5,106.5,111.1,113.1,118.1,120.1,124.4,127.2,131.6,135.7,138.6,141.9,143.9,145.8,147.8,151.5,152.3,154,156.6,158.5,160.5,162.5,163.5,165.6,165.7,166.9,167.8,168.5,169.8,169.8,170.3,171.6,172.1,171.8,173,174.4,175.8,177.7,179.5,181.1,183.2,184.8,185.7,188,189.9,190.8,191.8,193.4,194.8,197.5,198.3,199.2,200.7,201.6,201.8,203.5,205.8,208.2,202.8]
z1=[2.26,2.88,4.09,4.7,5.73,8.12,9,10.15,10.07,8.84,10.96,11.6,12.34,10.67,12.23,13.48,12.37,11.55,10.99,11.93,10.07,9.86,10.2,5.04,6.36,9.65,10.47,4.64,6.03,7.78,7.49,5.37,4.01,3.99,4.14,3.62,3.4,3.46,3.84,3.26,3.67,3.99,4.23,4.1,4.84,5.68,6.11,6.77,7,7.64,8.18,9.09,7.99,7.38,8.54,8.14,7.9,8.22,8.21,8.87,9.34,8.58,8.67,8.74,8.36,7.63,7.51,8.03,4.45,-0.4]

fig = go.Figure(data=[
    go.Surface(z=z, x=x, y=y, opacity=0.5, colorscale='rdbu', name='Target Slip'),
    go.Scatter3d(x=x1, y=y1, z=z1,
    name='Actual Slip Turn 4',
    mode='lines',
   # Only needed if I want dots instead of lines
    #marker=dict(
    #    size=4,
    #    color=z,
    #    colorscale='Viridis',
    #),
    line=dict(
        color='green',
        width=8
    )
    )
    ])
fig.update_layout(title='Target Slip vs Actual Slip - Turn 4 Redbull Ring', autosize=False,
                  width=1000, height=1000,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.update_layout(scene = dict(
                    xaxis_title='Lean Angle (degrees)',
                    yaxis_title='Speed (km/h)',
                    zaxis_title='Slip (%'))


fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import width
# ----> 2 import plotly.graph_objects as go
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# https://plotly.com/python/3d-surface-plots/

# %%
import pandas as pd

log = pd.read_csv("log1.csv")

#Remove second row that has value types and convert whole dataframe to number
log.drop(log.index[0], inplace=True)
log = log.apply(pd.to_numeric)

#Remove Negative Slip (braking)
brakingValues = log[log['slip']<0].index
log.drop(brakingValues, inplace=True)

#Convert All Lean Angles to positive
log['phi_lean'] = log['phi_lean'].abs()

speed = log['v_front']
slip = log['slip']
lean = log['phi_lean']

print(speed)
print(slip)
print(lean)

# %%
import pandas as pd
from turtle import width
import plotly.graph_objects as go
import numpy as np

log = pd.read_csv("log1.csv")

#Remove second row that has value types and convert whole dataframe to number
log.drop(log.index[0], inplace=True)
log = log.apply(pd.to_numeric)

#Remove Negative Slip (braking)
brakingValues = log[log['slip']<0].index
log.drop(brakingValues, inplace=True)

#Convert All Lean Angles to positive
log['phi_lean'] = log['phi_lean'].abs()

speed = log['v_front']
slip = log['slip']
lean = log['phi_lean']

# Target Variables from BMW Configurator
targetLean = [15,20,25,30,35,40,45,50,55,60]
targetSpeed = [50,65,85,105,125,145,165,185,205,225]
targetLean, targetSpeed = np.meshgrid(targetLean, targetSpeed)
targetSlip = np.array([
    [24,21.6,20.9,19.7,18.1,16.2,13.4,9.2,5.7,1.6],
    [22.3,21.7,21,19.8,18.2,16.4,13.8,9.4,5.7,1.8],
    [22.4,21.8,21.1,19.9,18.3,16.5,14.1,9.5,5.6,1.9],
    [22.6,22,21.2,20.1,18.4,16.6,14.2,9.6,5.7,2.1],
    [22.7,22.1,21.4,20.2,18.6,16.8,14.3,9.6,5.2,2],
    [22.8,22.2,21.5,20.3,18.7,16.8,14.3,9.6,5.1,1.8],
    [22.9,22.4,21.6,20.4,18.8,16.8,14.3,9.7,5.2,1.4],
    [23,22.5,21.8,20.6,18.9,16.9,14.2,9.9,5.9,2.2],
    [23.1,22.6,21.9,20.7,19,17,14.2,10.2,6.6,3.3],
    [23.2,22.7,22.1,20.8,19.1,17.1,14.3,10.4,7.1,4]
])
print(targetSlip)

actualLean=lean
actualSpeed=speed
actualSlip=slip

fig = go.Figure(data=[
    go.Surface(x=targetLean, y=targetSpeed, z=targetSlip, opacity=0.5, colorscale='rdbu', name='Target Slip'),
    go.Scatter3d(x=actualLean, y=actualSpeed, z=actualSlip,
    name='Actual Slip Turn 4',
    mode='lines',
   # Only needed if I want dots instead of lines
    #marker=dict(
    #    size=4,
    #    color=z,
    #    colorscale='Viridis',
    #),
    line=dict(
        color='green',
        width=8
    )
    )
    ])
fig.update_layout(title='Target Slip vs Actual Slip - Turn 5 Redbull Ring', autosize=False,
                  width=1000, height=1000,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.update_layout(scene = dict(
                    xaxis_title='Lean Angle (degrees)',
                    yaxis_title='Speed (km/h)',
                    zaxis_title='Slip (%'))


fig.show()
# Out:
# [[24.  21.6 20.9 19.7 18.1 16.2 13.4  9.2  5.7  1.6]
#  [22.3 21.7 21.  19.8 18.2 16.4 13.8  9.4  5.7  1.8]
#  [22.4 21.8 21.1 19.9 18.3 16.5 14.1  9.5  5.6  1.9]
#  [22.6 22.  21.2 20.1 18.4 16.6 14.2  9.6  5.7  2.1]
#  [22.7 22.1 21.4 20.2 18.6 16.8 14.3  9.6  5.2  2. ]
#  [22.8 22.2 21.5 20.3 18.7 16.8 14.3  9.6  5.1  1.8]
#  [22.9 22.4 21.6 20.4 18.8 16.8 14.3  9.7  5.2  1.4]
#  [23.  22.5 21.8 20.6 18.9 16.9 14.2  9.9  5.9  2.2]
#  [23.1 22.6 21.9 20.7 19.  17.  14.2 10.2  6.6  3.3]
#  [23.2 22.7 22.1 20.8 19.1 17.1 14.3 10.4  7.1  4. ]]
